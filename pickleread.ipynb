# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pickle
with open('/content/gdrive/My Drive/BTRS/bkk_section.pickle', 'rb') as handle:
    section_info = pickle.load(handle)

# %%
count = 0
for i in section_info:
  print(i,section_info[i])
  count +=1
  if count > 700:
    break
# Out:
# (0, 0) {'base': ((13.7653599, 100.5373324), (13.76552244, 100.53696334), 23), 'p1': array([ 13.7653599, 100.5373324]), 'p2': array([ 13.76552244, 100.53696334]), 'forward_line': ((13.765268382543127, 100.5372920942301), (13.765430922543127, 100.5369230342301)), 'backward_line': ((13.765613957456873, 100.5370036457699), (13.765451417456873, 100.5373727057699)), 'forward_avg_speed': -1, 'backward_avg_speed': -1, 'forward_speed_list': [], 'backward_speed_list': []}
# (0, 1) {'base': ((13.76552244, 100.53696334), (13.76568498, 100.53659428), 23), 'p1': array([ 13.76552244, 100.53696334]), 'p2': array([ 13.76568498, 100.53659428]), 'forward_line': ((13.765430922543127, 100.5369230342301), (13.765593462543126, 100.5365539742301)), 'backward_line': ((13.765776497456873, 100.5366345857699), (13.765613957456873, 100.5370036457699)), 'forward_avg_speed': -1, 'backward_avg_speed': -1, 'forward_speed_list': [], 'backward_speed_list': []}
# ...
